# %% [markdown]
# <a href="https://colab.research.google.com/github/RishithaDama/AI_agents/blob/main/CrewAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pip
# !pip install crewai crewai-tools
# !pip install -U langchain-google-genai

# %%
# !pip install litellm

# %%
from google.colab import userdata
API_KEY = userdata.get('api_key')

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

os.environ["GOOGLE_API_KEY"] = API_KEY

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite"
)

# %%
from crewai import Agent, Task, Crew, LLM

agent1 = Agent(
    role = "Motivational speaker",
    goal = "create an linkeidn post for job seekers",
    backstory = "An experienced mentor who inspires others",
    llm = "gemini/gemini-2.5-flash"
)

# %%
task = Task(
    description = "Write a short linkedin post to motivate job seekers on topic = {topic}",
    expected_output= "clean and humanised linkedin post",
    agent = agent1
)

# %%
crew = Crew(
    agents = [agent1],
    tasks = [task]
)

# %%
import asyncio

async def run():
    result = await crew.kickoff_async(inputs={"topic": "Dealing with rejections"})
    print(result)

await run()
